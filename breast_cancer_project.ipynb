# %% [markdown]
# <a href="https://colab.research.google.com/github/Hariom2227/heart-disease-prediction/blob/main/breast_cancer_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ucimlrepo

# fetch dataset
breast_cancer_wisconsin_original = fetch_ucirepo(id=15)

# data (as pandas dataframes)
X = breast_cancer_wisconsin_original.data.features
y = breast_cancer_wisconsin_original.data.targets

# metadata
print(breast_cancer_wisconsin_original.metadata)

# variable information
print(breast_cancer_wisconsin_original.variables)
# Out:
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 447, in run
#     conflicts = self._determine_conflicts(to_install)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 578, in _determine_conflicts
#     return check_install_conflicts(to_install)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/operations/check.py", line 101, in check_install_conflicts
# ...

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id=17)

# data (as pandas dataframes)
X = breast_cancer_wisconsin_diagnostic.data.features
y = breast_cancer_wisconsin_diagnostic.data.targets

# metadata
print(breast_cancer_wisconsin_diagnostic.metadata)

# variable information
print(breast_cancer_wisconsin_diagnostic.variables)
# Out:
# {'uci_id': 17, 'name': 'Breast Cancer Wisconsin (Diagnostic)', 'repository_url': 'https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic', 'data_url': 'https://archive.ics.uci.edu/static/public/17/data.csv', 'abstract': 'Diagnostic Wisconsin Breast Cancer Database.', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 569, 'num_features': 30, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['Diagnosis'], 'index_col': ['ID'], 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1993, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C5DW2B', 'creators': ['William Wolberg', 'Olvi Mangasarian', 'Nick Street', 'W. Street'], 'intro_paper': {'ID': 230, 'type': 'NATIVE', 'title': 'Nuclear feature extraction for breast tumor diagnosis', 'authors': 'W. Street, W. Wolberg, O. Mangasarian', 'venue': 'Electronic imaging', 'year': 1993, 'journal': None, 'DOI': 
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.concat([X, y], axis=1)
display(data)
# Out:
#      radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0      17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1      20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2      19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3      11.42     20.38       77.58   386.1      0.14250       0.28390
# 4      20.29     14.34      135.10  1297.0      0.10030       0.13280
# ..       ...       ...         ...     ...          ...           ...
# 564    21.56     22.39      142.00  1479.0      0.11100       0.11590
# 565    20.13     28.25      131.20  1261.0      0.09780       0.10340
# 566    16.60     28.08      108.30   858.1      0.08455       0.10230
# 567    20.60     29.33      140.10  1265.0      0.11780       0.27700
# 568     7.76     24.54       47.92   181.0      0.05263       0.04362
#
#      concavity1  concave_points1  symmetry1  fractal_dimension1  ...  \
# ...

# %%
data['Diagnosis']=data['Diagnosis'].map({'M':1,'B':0})
display(data)
# Out:
#      radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0      17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1      20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2      19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3      11.42     20.38       77.58   386.1      0.14250       0.28390
# 4      20.29     14.34      135.10  1297.0      0.10030       0.13280
# ..       ...       ...         ...     ...          ...           ...
# 564    21.56     22.39      142.00  1479.0      0.11100       0.11590
# 565    20.13     28.25      131.20  1261.0      0.09780       0.10340
# 566    16.60     28.08      108.30   858.1      0.08455       0.10230
# 567    20.60     29.33      140.10  1265.0      0.11780       0.27700
# 568     7.76     24.54       47.92   181.0      0.05263       0.04362
#
#      concavity1  concave_points1  symmetry1  fractal_dimension1  ...  \
# ...

# %%
y=data['Diagnosis']

# %%
plt.hist(data['Diagnosis'])
plt.title('Diagnosis(m=1,b=0')
plt.show()

# %%
plotnumber=1
plt.figure(figsize=(20,25))
for column in data:
  if plotnumber<=30:
    ax=plt.subplot(5,6,plotnumber)
    sns.distplot(data[column])
    plt.xlabel(column,fontsize=10)
  plotnumber+=1
plt.show()
# Out:
# /tmp/ipython-input-2325696683.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# /tmp/ipython-input-2325696683.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# /tmp/ipython-input-2325696683.py:6: UserWarning:
#
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
data.corr()
# Out:
#                      radius1  texture1  perimeter1     area1  smoothness1  \
# radius1             1.000000  0.323782    0.997855  0.987357     0.170581
# texture1            0.323782  1.000000    0.329533  0.321086    -0.023389
# perimeter1          0.997855  0.329533    1.000000  0.986507     0.207278
# area1               0.987357  0.321086    0.986507  1.000000     0.177028
# smoothness1         0.170581 -0.023389    0.207278  0.177028     1.000000
# compactness1        0.506124  0.236702    0.556936  0.498502     0.659123
# concavity1          0.676764  0.302418    0.716136  0.685983     0.521984
# concave_points1     0.822529  0.293464    0.850977  0.823269     0.553695
# symmetry1           0.147741  0.071401    0.183027  0.151293     0.557775
# fractal_dimension1 -0.311631 -0.076437   -0.261477 -0.283110     0.584792
# radius2             0.679090  0.275869    0.691765  0.732562     0.301467
# texture2           -0.097317  0.386358   -0.086761 -0.066280     0.068406
# ...

# %%
plt.figure(figsize=(15,15))
corr=data.corr()

mask=np.triu(np.ones_like(corr,dtype=bool,))
sns.heatmap(data.corr(),mask=mask ,linewidths=1,fmt="2f",annot=True)
plt.show()

# %%
corr_matrix=data.corr().abs()
tri_data=corr_matrix.mask(mask)
to_drop=[column for column in tri_data.columns if any(tri_data[column]>0.92)]
to_drop
# Out:
# ['radius1',
#  'perimeter1',
#  'area1',
#  'concavity1',
#  'radius2',
#  'perimeter2',
#  'radius3',
#  'perimeter3']

# %%
# Identify columns from original X that are in to_drop
columns_to_keep = [col for col in to_drop if col in X.columns]

# Filter the data DataFrame to keep only these columns
data = data[columns_to_keep]
x=data
x
# Out:
#      radius1  perimeter1   area1  concavity1  radius2  perimeter2  radius3  \
# 0      17.99      122.80  1001.0     0.30010   1.0950       8.589   25.380
# 1      20.57      132.90  1326.0     0.08690   0.5435       3.398   24.990
# 2      19.69      130.00  1203.0     0.19740   0.7456       4.585   23.570
# 3      11.42       77.58   386.1     0.24140   0.4956       3.445   14.910
# 4      20.29      135.10  1297.0     0.19800   0.7572       5.438   22.540
# ..       ...         ...     ...         ...      ...         ...      ...
# 564    21.56      142.00  1479.0     0.24390   1.1760       7.673   25.450
# 565    20.13      131.20  1261.0     0.14400   0.7655       5.203   23.690
# 566    16.60      108.30   858.1     0.09251   0.4564       3.425   18.980
# 567    20.60      140.10  1265.0     0.35140   0.7260       5.772   25.740
# 568     7.76       47.92   181.0     0.00000   0.3857       2.548    9.456
#
#      perimeter3
# 0        184.60
# 1        158.80
# ...

# %%
x
# Out:
#      radius1  perimeter1   area1  concavity1  radius2  perimeter2  radius3  \
# 0      17.99      122.80  1001.0     0.30010   1.0950       8.589   25.380
# 1      20.57      132.90  1326.0     0.08690   0.5435       3.398   24.990
# 2      19.69      130.00  1203.0     0.19740   0.7456       4.585   23.570
# 3      11.42       77.58   386.1     0.24140   0.4956       3.445   14.910
# 4      20.29      135.10  1297.0     0.19800   0.7572       5.438   22.540
# ..       ...         ...     ...         ...      ...         ...      ...
# 564    21.56      142.00  1479.0     0.24390   1.1760       7.673   25.450
# 565    20.13      131.20  1261.0     0.14400   0.7655       5.203   23.690
# 566    16.60      108.30   858.1     0.09251   0.4564       3.425   18.980
# 567    20.60      140.10  1265.0     0.35140   0.7260       5.772   25.740
# 568     7.76       47.92   181.0     0.00000   0.3857       2.548    9.456
#
#      perimeter3
# 0        184.60
# 1        158.80
# ...

# %%
x.shape
# Out:
# (569, 8)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from threading import local
from logging import logMultiprocessing
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
y_pred=lr.predict(X_test)
print(accuracy_score(y_test,y_pred))
con_matrix=confusion_matrix(y_test,y_pred)
print(con_matrix)
print(classification_report(y_test,y_pred))
# Out:
# 0.9824561403508771
# [[71  0]
#  [ 2 41]]
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        71
#            1       1.00      0.95      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
aac_report=classification_report(y_test,y_pred)
print(aac_report)
aac_score=accuracy_score(y_test,y_pred)
print(aac_score)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        71
#            1       1.00      0.95      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# 0.9824561403508771

# %%
from sklearn.svm import SVC
svm=SVC(kernel='linear')
svm.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
sns.

# %%
# Select two features for visualization
X_vis = X_train[:, [0, 1]]  # Using the first two scaled features
y_vis = y_train

# Train a new SVC model on the selected features for visualization
svm_vis = SVC(kernel='rbf')
svm_vis.fit(X_vis, y_vis)

# Create a meshgrid for plotting the decision boundary
x_min, x_max = X_vis[:, 0].min() - 1, X_vis[:, 0].max() + 1
y_min, y_max = X_vis[:, 1].min() - 1, X_vis[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))

# Predict the class for each point in the meshgrid
Z = svm_vis.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the decision boundary and the data points
plt.contourf(xx, yy, Z, alpha=0.8)
plt.scatter(X_vis[:, 0], X_vis[:, 1], c=y_vis, edgecolors='k', marker='o')
plt.title('SVC Decision Boundary (using first two features)')
plt.xlabel('Feature 1 (Scaled)')
plt.ylabel('Feature 2 (Scaled)')
plt.show()

# %%
# Reload the original data
data = pd.concat([X, y], axis=1)

# Keep only the columns in to_drop
data = data[to_drop]
display(data)
# Out:
#      radius1  perimeter1   area1  concavity1  radius2  perimeter2  radius3  \
# 0      17.99      122.80  1001.0     0.30010   1.0950       8.589   25.380
# 1      20.57      132.90  1326.0     0.08690   0.5435       3.398   24.990
# 2      19.69      130.00  1203.0     0.19740   0.7456       4.585   23.570
# 3      11.42       77.58   386.1     0.24140   0.4956       3.445   14.910
# 4      20.29      135.10  1297.0     0.19800   0.7572       5.438   22.540
# ..       ...         ...     ...         ...      ...         ...      ...
# 564    21.56      142.00  1479.0     0.24390   1.1760       7.673   25.450
# 565    20.13      131.20  1261.0     0.14400   0.7655       5.203   23.690
# 566    16.60      108.30   858.1     0.09251   0.4564       3.425   18.980
# 567    20.60      140.10  1265.0     0.35140   0.7260       5.772   25.740
# 568     7.76       47.92   181.0     0.00000   0.3857       2.548    9.456
#
#      perimeter3
# 0        184.60
# 1        158.80
# ...

# %%
# Generate random data with the same number of features as the training data
random_data = np.random.rand(1, X_train.shape[1])

# Scale the random data using the fitted scaler
scaled_random_data = sc.transform(random_data)

# Make a prediction using the logistic regression model
prediction = lr.predict_proba(scaled_random_data)[:, 1] # Get the probability of the positive class

# Check the prediction and print the result
if prediction[0] > 0.5: # Access the probability of the positive class
  print("Prediction is more than 50%: Dangerous")
else:
  print("Prediction is 50% or less: Keep precaution")
# Out:
# Prediction is 50% or less: Keep precaution
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
X_train
# Out:
# array([[-1.44075296, -1.36208497, -1.1391179 , ..., -0.47041357,
#         -1.23286131, -1.24792009],
#        [ 1.97409619,  2.09167167,  1.85197292, ...,  0.75195659,
#          2.17331385,  2.08161691],
#        [-1.39998202, -1.34520926, -1.10978518, ..., -0.12095781,
#         -1.29528358, -1.24522047],
#        ...,
#        [ 0.04880192, -0.06512547, -0.06142266, ..., -0.97362021,
#         -0.27571985, -0.37984081],
#        [-0.03896885, -0.03137406, -0.15477966, ..., -0.60719916,
#          0.16747826,  0.20387802],
#        [-0.54860557, -0.60350155, -0.5518995 , ..., -0.80971917,
#         -0.60239639, -0.67559968]])
